# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
sales = pd.read_csv('sales_predictions.csv')

# %%
sales
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %%
sns.relplot(x="date", y="item_price", data=sales)

# %%
row = sales.sample(n = 30) 
sns.relplot(x="item_price", y="date", data=row)

# %%
row = sales.sample(n = 50) 
row["date"] = pd.to_datetime(row["date"], format='%d.%m.%Y', errors='ignore')
sns.relplot(x="date", y="item_price", data=row)
